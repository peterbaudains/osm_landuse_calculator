# %%
from osmlu import osm_lu_classifier

# %%
lu_classification, coverage, gdf = osm_lu_classifier(lon=-1.556, lat=53.803, buffer=500)

# %%
print(lu_classification)
# Out:
# lu_class
# residential      0.581007
# commercial       0.119715
# grass            0.099702
# park             0.047185
# construction     0.040764
# garden           0.039786
# retail           0.023766
# sports_centre    0.018826
# brownfield       0.005732
# pitch            0.005687
# religious        0.005504
# wood             0.004678
# water            0.003282
# scrub            0.002376
# industrial       0.001261
# playground       0.000428
# flowerbed        0.000300
# Name: area, dtype: float64

# %%
print('%% coverage = %.2f' % (coverage))
# Out:
# % coverage = 36.39

# %%
gdf.plot('lu_class', categorical=True, figsize=(8,8), alpha=0.2, legend=True)
# Out:
# <AxesSubplot: >
